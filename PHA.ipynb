# %% [markdown]
# Orbits for POtentially Hazardous Objects
# https://www.minorplanetcenter.net/data

# %%
import numpy as np
import pandas as pd

#Specify the path of the file to be read.
path =r'C:\Users\rrp\Documents\ox-p4ds\notebooks\Asteroidproject\PHA.txt'

#Set the max columns, so that all the fields are displayed in the screen
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 2000)

#No column names were provided in the file, hence specify it here
names = ['Number', 'Abs_MagH', 'SlopeG','Epoch', 'EpochMA','ArgPer','LongAscendingNode','Inclination','Eccentricity','MeanDM','SMA','Uncertainity','Ref','Observations','Oppositions','SingleMultiple','Residual','Coarse','Precise','Computer','Hexdigit','Designation1','Designation2','LastOb']

#Read files to a dataframe df.
pha = pd.read_fwf(path, header = None,names=names)

# %%
pha.sample(10)
# Out:
#      Number  Abs_MagH  SlopeG  Epoch    EpochMA     ArgPer  LongAscendingNode  Inclination  Eccentricity    MeanDM       SMA Uncertainity        Ref  Observations  Oppositions SingleMultiple  Residual Coarse Precise  Computer Hexdigit Designation1 Designation2    LastOb
# 321   K01T0      22.0    0.15  K194R  187.58994  227.37243           50.40152      3.26597      0.647156  0.418366  1.770511            2  MPO260735           119            2      2001-2013      0.47    M-v     3Eh    MPCALB     8803          NaN     2001 TA2  20130330
# 1092  K15J0      20.8    0.15  K194R   85.12921   16.75354          268.01450      8.51625      0.505140  0.320596  2.114288            0  E2018-U80           665            2      2015-2018      0.27    M-v     3Eh  MPCLINUX     8804          NaN     2015 JY1  20181029
# ...

# %% [markdown]
# Please note that the column 'Readable designation' in the PHA.txt file is read as 2 different columns in the dataframe above (Designation1 and Designation2). I am not clear about the importance of that column, you may need to concatenate the columns into one column, if required.
